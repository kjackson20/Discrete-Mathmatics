# %% [markdown]
# <a href="https://colab.research.google.com/github/kjackson20/Discrete-Mathmatics/blob/main/DiscreteMathematicsProjectPart_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Part 5 : CPSMA 3913-01 Dr. Matthew Lynam Discrete Mathematics
#
# ## Project Name: Module 5: Structures
#
# ### Kiara Jackson, StudentID#: 204074

# %% [markdown]
# ## 1. Compute using modulo arithmetic

# %% [markdown]
# ![chalkboard-with-math-elements_1411-88.jpg.avif](data:image/avif;base64,...)

# %% [markdown]
# (a) Convert the number following number into base ten:
#
# $$24036_7$$

# %% [markdown]
# $$(2 x 7^4) + (4 x 7^3) + (0 x 7^2) + (3 x 7^1) + (6 x 7^0)$$

# %%
print("Enter the number you want to convert to base 10: ")
number = input()

length = len(number)
print("Enter the base of the number: ")
base = input()
s = 0
for i in range(len(number)):
    length = length - 1
    
    s = number[i] * (int(base) ** length) 
    s += s

digits = {c: i for i, c in enumerate('0123456789abcdefghijklmnopqrstuvwxyz')}

s = 0
base = int(7)
for i, digit in enumerate(reversed(number.lower())):
  s += digits[digit] * (base ** i)
  


def parse_number(number, base):
    return sum(digits[digit] * (base ** i)
               for i, digit in enumerate(reversed(number.lower())))

print(parse_number(number, int(base)))
print(s)]
# Out:
# Enter the number you want to convert to base 10:
# 24036
# Enter the base of the number:
# 7
# 6201
# 6201

# %% [markdown]
# I just want to personally thank Roger for providing this link from Stackoverflow: https://stackoverflow.com/questions/26929227/base-converter-in-python
#
# I was pulling my hair out trying to find an example or code to use for this portion of the project. I searched all over the internet!
#
# So thank you again, Roger!

# %% [markdown]
# ![pulling.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# (b) Convert the hexadecimal number 72e3 or 0x72e3 into base ten.

# %% [markdown]
# Here we go with more MATH!

# %%
import math

x = int("72e3", 16)

# %%
import math

print(int("0x72e3",0))
# Out:
# 29411

# %% [markdown]
# (c) Convert 3735928559 into hexadecimal.

# %% [markdown]
# This section was probably the easiest part of the project. Well, other then typing my name and student ID number.
# So, I am going to type it again to make myself feel better about this project.
#
# Kiara Jackson
#
# StudentID#: 204074

# %%
import math

x = hex(3735928559)
print(x)
# Out:
# 0xdeadbeef

# %% [markdown]
# (d) Using two’s complement preform the base ten subtraction 25 − 37. Check your answer.

# %% [markdown]
# Part "d" is brought to you by more MATH !
#
# I threw everything in here, but the kitchen sink!

# %% [markdown]
# For the finale question, we are ask use two's complement preformthe base ten subtraction:
# $$25-37$$

# %% [markdown]
# Binary:
#
# 25 converted to binary 00011001
#
# -37 converted to binary 11011010. Since the number is negative, it will be changed to 00100101 by switching 1 to 0 and 0 to 1.

# %% [markdown]
# Now, I know there is not a two's complement built into the system. I decied to include them anyway. Also, I was able to compute -37.
#
# I know it does not work that way, but with a click of a button, ANYTHING IS POSSIBLE!

# %%
import math

int('00011001',2)
# Out:
# 25

# %%
import math

int('-00100101',2)
# Out:
# -37

# %%
import math

bin25 = bin(25)

bin25
# Out:
# '0b11001'

# %%
import math

bin37 = bin(37)

bin37
# Out:
# '0b100101'

# %%
import math

25 - 37
# Out:
# -12

# %% [markdown]
# Decimal value:
# $$25 – 37 = -12$$
#
# Binary value:
# $$00011001 – 00100101 = -01100$$

# %%
import math

def flipit(list7binary):
  newlist = []
  for i in list7binary:
    if i == '0':
      newlist.append('1')
    else:
      newlist.append('0')
  return newlist

flipit(['0','0','0','1','1','0','0','1'])
# Out:
# ['1', '1', '1', '0', '0', '1', '1', '0']

# %%
import math

twoscomplement(25)
# Out:
# '00011001'

# %%
import math

def addone(list7binary):
  counter = 7
  list7binary[counter] = str(1 + int(list7binary[counter]))
  while list7binary[counter]=='2':
    list7binary[counter] = '0'
    counter -= 1
    list7binary[counter] = str(1 + int(list7binary[counter]))
  return list7binary

addone(['0','0','1','0','0','1','0','1'])
# Out:
# ['0', '0', '1', '0', '0', '1', '1', '0']

# %%
import math

twoscomplement(-37)
# Out:
# '11011011'

# %% [markdown]
# The computer system is only aware of true or false, on or off, and 0 or 1. Digit "0" represents "off" and "1" represents "on". The binary system uses both "0" and "1". The hexadecimal systems base is "16", which can represent a group of binary digits with single-digits. This makes the conversion from binary to hexadecimal and hexadecimal to binary, simply easier.

# %% [markdown]
# ![how-to-end-a-video-presentation.jpg](data:image/jpeg;base64,...)
