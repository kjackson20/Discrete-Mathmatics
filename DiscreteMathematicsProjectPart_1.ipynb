# %% [markdown]
# <a href="https://colab.research.google.com/github/kjackson20/Discrete-Mathmatics/blob/main/DiscreteMathematicsProjectPart_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # : CPSMA 3913-01 [Dr. Matthew Lynam](https://github.com/nurfnick) Discrete Mathematics
#
# ## Project Name: Module 1: Sets
#
# ### Kiara Jackson, StudentID#: 204074

# %% [markdown]
# ## 1 Sets

# %% [markdown]
# The theme of my project will be the types of dinosaurs grouped according to the types of food that they eat.
# Set **A** will be the dinosaurs that are Carnivores, set **B** will be the dinosaurs that are Herbivores, and set **C** will be the dinosaurs that are Omnivores.
#
# ![Dinosaur-Sorting-Herb-Carn-Omn-L_1000x.jpg.webp](data:image/webp;base64,...)

# %%
Carnivores = {'Velociraptor', 'Giganotosaurus', 'Tyrannosaurus rex', 'Alectrosaurus', 'Deinonychus'}
Herbivores = {'Triceratops', 'Iguanodon', 'Stegosaurus', 'Apatosaurus', 'Brachiosaurus'}
Omnivores = ['Struthiomimus', 'Ornithomimus', 'Nomingia', 'Chirostenotes', 'Abrictosaurus']
# then do some coding that does that!  Try to adhere to Clean Code principle as much as possible!

# %% [markdown]
# A **universal set** is defined as a larger set that is formed from two or more sets. My universal set "U" will consist of all the types of dinosaurs based on the foods that they eat.

# %%
SetofSets = [Carnivores, Herbivores, Omnivores]
U = set
for dinosaurs in  SetofSets:
  U = U.union (dinosaurs)

U
# Out:
# {'Abrictosaurus',
#  'Alectrosaurus',
#  'Apatosaurus',
#  'Brachiosaurus',
#  'Chirostenotes',
#  'Deinonychus',
#  'Giganotosaurus',
#  'Iguanodon',
#  'Nomingia',
#  'Ornithomimus',
#  'Stegosaurus',
#  'Struthiomimus',
#  'Triceratops',
#  'Tyrannosaurus rex',
#  'Velociraptor'}

# %% [markdown]
# Set **D** are the dinosaurs that are grouped according to the type of food that they eat.

# %%
D = ['Buitreraptor', 'Eotriceratops', 'Kritosaurus', 'Protarchaeopteryx', 'Oviraptor']

# %% [markdown]
# A **union** are all of the elements in both sets.

# %%
UnionAB = [Carnivores, Herbivores]
for a in Carnivores:
  UnionAB.append(Carnivores)
for b in Herbivores:
  UnionAB.append(Herbivores)

UnionAB
# Out:
# ['D',
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  'D',
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'}]

# %%
UnionAC = [Carnivores, Omnivores]
for a in Carnivores:
  UnionAC.append(Carnivores)
for c in Omnivores:
  UnionAC.append(Omnivores)

UnionAC
# Out:
# ['D',
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  'D',
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus']]

# %%
UnionBC = [Herbivores, Omnivores]
for b in Herbivores:
  UnionBC.append(Herbivores)
for c in Omnivores:
  UnionBC.append(Omnivores)

UnionBC
# Out:
# [{'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
# ...

# %% [markdown]
# An **intersection** are all the elements that each set has in common.

# %%
IntersectionAB = [Carnivores, Herbivores]
for a in Carnivores:
  if b in Herbivores:
    IntersectionAB.append(a)

IntersectionAB
# Out:
# ['D',
#  {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  'D']

# %%
IntersectionAC = [Carnivores, Omnivores]
for a in Carnivores:
  if c in Omnivores:
    IntersectionAC.append(a)

IntersectionAC
# Out:
# ['D',
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  'D']

# %%
IntersectionBC = [Herbivores, Omnivores]
for b in Herbivores:
  if c in Omnivores:
    IntersectionBC.append(a)

IntersectionBC
# Out:
# [{'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  ['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  'D',
#  'D',
#  'D',
#  'D',
#  'D']

# %% [markdown]
# It does not matter which set is called first, two sets can be equal if they contain the same elements.

# %%
ComplementA = [Carnivores]
for u in U:
  if u not in Carnivores:
    ComplementA.append(u)

ComplementA
# Out:
# ['D',
#  'Stegosaurus',
#  'Triceratops',
#  'Chirostenotes',
#  'Deinonychus',
#  'Struthiomimus',
#  'Brachiosaurus',
#  'Tyrannosaurus rex',
#  'Apatosaurus',
#  'Giganotosaurus',
#  'Iguanodon',
#  'Velociraptor',
#  'Ornithomimus',
#  'Abrictosaurus',
#  'Alectrosaurus',
#  'Nomingia']

# %%
ComplementB = [Herbivores]
for u in U:
  if u not in Herbivores:
    ComplementB.append(u)

ComplementB
# Out:
# [{'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#  'Chirostenotes',
#  'Deinonychus',
#  'Struthiomimus',
#  'Tyrannosaurus rex',
#  'Giganotosaurus',
#  'Velociraptor',
#  'Ornithomimus',
#  'Abrictosaurus',
#  'Alectrosaurus',
#  'Nomingia']

# %%
ComplementC = [Omnivores]
for u in U:
  if u not in Omnivores:
    ComplementC.append(u)

ComplementC
# Out:
# [['Struthiomimus',
#   'Ornithomimus',
#   'Nomingia',
#   'Chirostenotes',
#   'Abrictosaurus'],
#  'Stegosaurus',
#  'Triceratops',
#  'Deinonychus',
#  'Brachiosaurus',
#  'Tyrannosaurus rex',
#  'Apatosaurus',
#  'Giganotosaurus',
#  'Iguanodon',
#  'Velociraptor',
#  'Alectrosaurus']

# %% [markdown]
# A **subset** is a aet of elements that are also in another set. Set A is a subset of set B because all of the elements of set A are present in set B.

# %% [markdown]
# A **power set** is the set that contains all subsets of a given set. The power set of U would have 15 elements.

# %%
def DPpowerset (Carnivores, Herbivores, Omnivores):
  powerset = [[Carnivores, Herbivores, Omnivores]]
  for i in dinosaurs:
   for sett in powerset:
     powerset = powerset + [sett + [i]]
   return powerset  

DPpowerset(Carnivores, Herbivores, Omnivores)
# Out:
# [['D',
#   {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#   ['Struthiomimus',
#    'Ornithomimus',
#    'Nomingia',
#    'Chirostenotes',
#    'Abrictosaurus']],
#  ['D',
#   {'Apatosaurus', 'Brachiosaurus', 'Iguanodon', 'Stegosaurus', 'Triceratops'},
#   ['Struthiomimus',
#    'Ornithomimus',
#    'Nomingia',
#    'Chirostenotes',
#    'Abrictosaurus'],
#   'D']]
