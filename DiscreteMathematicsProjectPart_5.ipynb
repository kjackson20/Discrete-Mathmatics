# %% [markdown]
# <a href="https://colab.research.google.com/github/kjackson20/Discrete-Mathmatics/blob/main/DiscreteMathematicsProjectPart_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Part 5 : CPSMA 3913-01 Dr. Matthew Lynam Discrete Mathematics
#
# ## Project Name: Module 5: Structures
#
# ### Kiara Jackson, StudentID#: 204074

# %% [markdown]
# ## 1 Structures

# %% [markdown]
# So, it has been asked that we tell a story about somtheing that has happened in our life. So, I figured I would tell a funny story.
#
# Well, funny to me and I hope for to you too!
#
# I mean, who does not like funny stories?
#
# I know I do!

# %% [markdown]
# (a, b, & c)
#
# My structure will be based on the time that I fell and rolled down the stairs.
#
# I know what you are thinking. Why would she think this is funny? Well becasue it was, and I am the kind of person that enjoys a good laugh. Even if it is about me!

# %%
import graphviz

dot = graphviz.Graph(comment='The Fall')

dot.node('A', 'Laundry Day')
dot.node('B', 'Kiara')
dot.node('C', 'Baskets/Bags Clothes')
dot.node('D', 'Rolled')
dot.node('E', 'Down the Stairs')
dot.node('F', 'Gathered')
dot.node('G', 'Robert')
dot.node('H', 'THAT IS NOT A GOOD IDEA!')
dot.node('I', 'Falling Out')
dot.node('J', 'Disbelief')

dot.edges(['AB','BF','GF','FC','CD','DE','CI','GH','GJ','BD'])
dot

dot

# %% [markdown]
# So, it all took place on a Sunday. Sunday's in my home are considered laundry days.
#
# Kiara and Robert, went around the house and gathered all of the baskets/bags of clothes that needed to be washed that day.
# ![images.png](data:image/png;base64,...)

# %%
import graphviz

dot = graphviz.Graph(comment='The Fall')

dot.node('A', 'Laundry Day')
dot.node('B', 'Kiara')
dot.node('C', 'Baskets/Bags Clothes')
dot.node('F', 'Gathered')
dot.node('G', 'Robert')

dot.edges(['AB','BF','GF','FC'])
dot

dot

# %% [markdown]
# Now, there is one thing that I forgot to mention. Kiara always comes up with some bright idea and that idea always works out perfectly in her mind. When it comes to executing that idea, it does not always go as planned!
#
# But hey, we LIVE and we LEARN!

# %% [markdown]
# so, after gathering all of the baskets/bags of clothes. Kiara and Robert met up at the top of the stairs. Robert would always carry the baskets/bags down the stairs, but on this particular day Kiara came up with one of her bright ideas. Kiara was going to help Robert bring the baskets/bags downstair.
#
# I said bring instead if carry, because she was not going to carry them down the stairs. She was going to roll them down the stairs.
#
# Kiara got the bright idea to roll them down the stairs while still in the baskets/bags.
#
# **(By the way, Robert is Kiara's husband. If I forgot to mention that.)**

# %%
import graphviz

dot = graphviz.Graph(comment='The Fall')

dot.node('A', 'Laundry Day')
dot.node('B', 'Kiara')
dot.node('C', 'Baskets/Bags Clothes')
dot.node('D', 'Rolled')
dot.node('E', 'Down the Stairs')
dot.node('F', 'Gathered')
dot.node('G', 'Robert')


dot.edges(['AB','BF','GF','FC','CD','DE'])
dot

dot

# %% [markdown]
# Now, Kiara new that there was a possibiltiy that the clothes could fall out of the basket/bags. So she did her best to make sure that they were all secure. So the clothes would not fall out.
#
# As Kiara began to roll the baskets/bags of clothes down the stairs. Some of the clothes started falling out and landing on the stairs.
#
# While all of this was happening, you can hear Robert say, "THAT IS NOT A GOOD IDEA!"

# %%
import graphviz

dot = graphviz.Graph(comment='The Fall')

dot.node('A', 'Laundry Day')
dot.node('B', 'Kiara')
dot.node('C', 'Baskets/Bags Clothes')
dot.node('D', 'Rolled')
dot.node('E', 'Down the Stairs')
dot.node('F', 'Gathered')
dot.node('G', 'Robert')
dot.node('H', 'THAT IS NOT A GOOD IDEA!')
dot.node('I', 'Falling Out')

dot.edges(['AB','BF','GF','FC','CD','DE','CI','GH'])
dot

dot

# %% [markdown]
# Apparantely, Robert knew something was going to happen.
#
# Ever since that day, I still wonder how he knew. I am starting to believe that he may be PSYCHIC!
#
# HA HA! HA! HA!
#
# ![depositphotos_618829728-stock-illustration-wizard-looking-crystal-ball-predict.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Somebody had to go on the stairs to pick up all of the clothes that fell out. Robert looked and said, "I am not doing it. You shoud have just let me carry them."
#
# So the brave person that I am. I selected myself to go pick up all of the clothes. Did you see what I did there? Selected myself. No, I am just playing. I had no choice but to go.
#
# As I am walking down the stairs picking up the clothes, I tripped and rolled. That is how I fell down the stairs.

# %% [markdown]
# ![a-bad-fall-some-ms-lessons-learned-1440x810.jpg](data:image/jpeg;base64,...)

# %%
import graphviz

dot = graphviz.Graph(comment='The Fall')

dot.node('A', 'Laundry Day')
dot.node('B', 'Kiara')
dot.node('C', 'Baskets/Bags Clothes')
dot.node('D', 'Rolled')
dot.node('E', 'Down the Stairs')
dot.node('F', 'Gathered')
dot.node('G', 'Robert')
dot.node('H', 'THAT IS NOT A GOOD IDEA!')
dot.node('I', 'Falling Out')

dot.edges(['AB','BF','GF','FC','CD','DE','CI','GH','BD'])
dot

dot

# %% [markdown]
# Robert looked in DISBELIEF, and Kiara got up and started to laugh.
#
# Robert did not laugh. He did not think it was funny!

# %%
import graphviz

dot = graphviz.Graph(comment='The Fall')

dot.node('A', 'Laundry Day')
dot.node('B', 'Kiara')
dot.node('C', 'Baskets/Bags Clothes')
dot.node('D', 'Rolled')
dot.node('E', 'Down the Stairs')
dot.node('F', 'Gathered')
dot.node('G', 'Robert')
dot.node('H', 'THAT IS NOT A GOOD IDEA!')
dot.node('I', 'Falling Out')
dot.node('J', 'Disbelief')

dot.edges(['AB','BF','GF','FC','CD','DE','CI','GH','GJ','BD'])
dot

dot

# %% [markdown]
# (d)
#
# The **degree of a vertex** is the number of edges that are incident to a vertex.

# %% [markdown]
# (e)
#
# A cycle in a graph is a non-empty trail in which only the first and last vertices are equal.
#
# A cycle in my structure does not exist. In order to be a cycle in a graph, the first and the last verticies have to be equal. We consider them equal when they are the same and connected. In my structure they are not equal, and it is impossible to start at a vertex and end with one.
